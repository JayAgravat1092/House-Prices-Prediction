# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\jayag\Desktop\Marwadi\SEM-5\DSE\Datasets\Diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
import pandas as pd

# Assume 'df' is your DataFrame with 'age' and 'bmi' columns

# Create a new feature by adding 'age' and 'bmi'
df['age_bmi_combined'] = df['Age'] ** 3 + df['BMI'] + 100
df['SkinThickness_Age'] = df['Age'] ** 5 + df['SkinThickness'] + 20 
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  age_bmi_combined  \
# ...

# %%
import seaborn as sns

# %%
sns.histplot(df['BMI'],kde=True)
# Out:
# <Axes: xlabel='BMI', ylabel='Count'>

# %%
sns.boxplot
# Out:
# <function seaborn.categorical.boxplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, width=0.8, dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None, **kwargs)>

# %%
sns.boxplot(data=df, y='Age',x='Outcome',color='skyblue')
# Out:
# <Axes: xlabel='Outcome', ylabel='Age'>

# %%
# Calculate the mean and standard deviation
mean_value = df['BloodPressure'].mean()
std_dev = df['BloodPressure'].std()

# Set a threshold for identifying outliers (e.g., 3 standard deviations)
threshold = 3

# Replace outliers with the mean
df['BloodPressure'] = np.where((df['BloodPressure'] - mean_value).abs() > threshold * std_dev,
                             mean_value,
                             df['BloodPressure'])
df['Insulin'] = np.where((df['Insulin'] - mean_value).abs() > threshold * std_dev,
                             mean_value,
                             df['Insulin'])

# %%
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Filter the dataframe to keep only the rows within the bounds
    df_filtered = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    
    return df_filtered


# Remove outliers from the selected column
df_no_outliers = remove_outliers_iqr(df,'Pregnancies')
print(f"Number of removed outliers: {len(df) - len(df_no_outliers)}")

df_no_outliers = remove_outliers_iqr(df,'Glucose')
print(f"Number of removed outliers: {len(df) - len(df_no_outliers)}")

df_no_outliers = remove_outliers_iqr(df,'BloodPressure')
# Print the number of removed outliers
print(f"Number of removed outliers: {len(df) - len(df_no_outliers)}")

df_no_outliers = remove_outliers_iqr(df,'Insulin')
# Print the number of removed outliers
print(f"Number of removed outliers: {len(df) - len(df_no_outliers)}")

df_no_outliers = remove_outliers_iqr(df,'BMI')
# Print the number of removed outliers
print(f"Number of removed outliers: {len(df) - len(df_no_outliers)}")

df_no_outliers = remove_outliers_iqr(df,'DiabetesPedigreeFunction')
# Print the number of removed outliers
print(f"Number of removed outliers: {len(df) - len(df_no_outliers)}")

df_no_outliers = remove_outliers_iqr(df,'Age')
# Print the number of removed outliers
print(f"Number of removed outliers: {len(df) - len(df_no_outliers)}")
# Out:
# Number of removed outliers: 4
# Number of removed outliers: 5
# Number of removed outliers: 14
# Number of removed outliers: 202
# Number of removed outliers: 19
# Number of removed outliers: 29
# Number of removed outliers: 9

# %%
from sklearn.model_selection import train_test_split
y=df_no_outliers['Outcome']
x=df_no_outliers.drop('Outcome',axis=1)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
# Standardize the features (optional, but can be beneficial for Logistic Regression)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
model=DecisionTreeClassifier(random_state=42)
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred=model.predict(x_test)

# %%
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.7236842105263158

# %%
from sklearn.linear_model import LogisticRegression
# Create and train the Logistic Regression model
model = LogisticRegression(random_state=42)
model.fit(X_train_scaled, y_train)

# Make predictions on the testing set
y_pred = model.predict(X_test_scaled)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# Print evaluation metrics
print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", classification_rep)
# Out:
# Accuracy: 0.7631578947368421
# Confusion Matrix:
#  [[88 10]
#  [26 28]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83        98
#            1       0.74      0.52      0.61        54
#
#     accuracy                           0.76       152
#    macro avg       0.75      0.71      0.72       152
# weighted avg       0.76      0.76      0.75       152

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Create and train the Random Forest model
model = RandomForestClassifier(random_state=42)
model.fit(x_train, y_train)

# Make predictions on the testing set
y_pred = model.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

# Print evaluation metrics
print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", classification_rep)
# Out:
# Accuracy: 0.7631578947368421
# Confusion Matrix:
#  [[86 12]
#  [24 30]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83        98
#            1       0.71      0.56      0.63        54
#
#     accuracy                           0.76       152
#    macro avg       0.75      0.72      0.73       152
# weighted avg       0.76      0.76      0.76       152
